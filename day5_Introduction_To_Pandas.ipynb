# %%
import pandas as pd
data ={

       "Name": ["John", "Mary", "Peter", "Abdul"],
       "Score": [80, 90, 75, 100]
}

df = pd.DataFrame(data)
print(df)
# Out:
#     Name  Score
# 0   John     80
# 1   Mary     90
# 2  Peter     75
# 3  Abdul    100
