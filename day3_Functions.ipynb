# %%
def greet(name):
  return (f"Hello {name}")
print(greet("Yusuff"))
# Out:
# Hello Yusuff

# %%
def greet(name="Yusuff"):
  print(f"Hello {name}")
greet()
# Out:
# Hello Yusuff

# %%
def calculate_total(price, quantity):
  return f"Total: {price * quantity}"
print(calculate_total(5,10))
# Out:
# Total: 50
